# %% [markdown]
# # Демонстрационный ноутбук
#
# Ячейка **Markdown**: заголовок, список, `инлайн-код`.
#
# - считаем площадь круга
# - выводим текст и картинку

# %%
import math


def area(r):
    return math.pi * r * r


print(round(area(2), 3))
area(2)
# Out:
# 12.566
# 12.566370614359172

# %%
# вывод-картинка (PNG, вложён в ноутбук)
render_swatch()
